# %% [markdown]
# # BATTLE OF NEIGBHOORHOODS
# **NEW YORK CITY VS TORONTO

# %% [markdown]
# # Problem Statement

# %% [markdown]
# 1)Understand the similarities and differences of neighborhoods between Scarborough borough in Toronto and Queens borough in New York City.
#
# 2)Select the best neighborhood for a Fortune 500 company to move its headquarters based on venues.

# %% [markdown]
# # Objectives

# %% [markdown]
# 1) Collect the neighborhoods top venues using Foursquare.
#
# 2)Form neighborhood based on venue categories using unsupervised k-means clustering algorithm.
#
# 3)Identify and understand the similarities and differences between Scarborough and Queens neighborhoods to obtain insights into the neighborhoods.

# %% [markdown]
# # Comparison between Neighborhoods

# %% [markdown]
# # Scarborough vs Queens

# %% [markdown]
# *Scarborough has 79 distinct venues in 52 categories.
#
# *The most common venues in Scarborough are coffee
# shops, international restaurants, and skating rinks.
#
# *Queens has 1760 distinct venues in 269 categories.
#
# *The most common venues in Queens are bodegas,
# bakeries, coffee shops, and parks.

# %% [markdown]
# # Conclusion

# %% [markdown]
# Based on the quantity of venues and variety of venues, Queens is a better choice than Scarborough to relocate the headquarters of theFortune 500 company. Queens offer a greater
# amount of gyms, grocery stores, restaurants for individual and families of the employees.
